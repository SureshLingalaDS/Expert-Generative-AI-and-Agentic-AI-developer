# %%
def greet():
    print("Hello This is first function")
greet()
# Out:
# Hello This is first function

# %%
def greet():
    print("Hello This is first function")
greet()
greet()
# Out:
# Hello This is first function
# Hello This is first function

# %%
def add():
    a=10
    b=20
    c=a+b
    print("Sum is :", c)
add()
# Out:
# Sum is : 30

# %%
def add( a, b):
 c=a+b
 print(c)
add(10,20)
# Out:
# 30

# %%
def add(a, b,c):
 d=a+b+c
 print(d)

add(20,30,40)
# Out:
# 90

# %%
def add(a,b): 
    c = a+b
    return c
    
add(4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2     c = a+b
#       3     return c
# ----> 5 add(4,5,6)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(a,b,c): 
    c = a+b
    return c
    
add(4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2     c = a+b
#       3     return c
# ----> 5 add(4,5)
#
# TypeError: add() missing 1 required positional argument: 'c'

# %%
def person(name,age):
    print(name)
    print(age)
person('Suresh', 40)
# Out:
# Suresh
# 40

# %%
def person(name,age=18):
    print(name)
    print(age)
person('Suresh')
# Out:
# Suresh
# 18

# %%
def person(name,age):
    print(name)
    print(age)
    
person(22, 'suresh')
# Out:
# 22
# suresh

# %%
def person(name,age):
    print(name)
    print(age)
     
person('suresh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('suresh')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age):
    print(name)
    print(age - 1)
     
person(22, 'suresh')
# Out:
# 22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2     print(name)
#       3     print(age - 1)
# ----> 5 person(22, 'suresh')
#
# Cell In[18], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print(name)
# ----> 3     print(age - 1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
def person(name,age):
    print(name)
    print(age - 1)
     
person('nit',22)
# Out:
# nit
# 21

# %%
def person(name,age):
    print(name)
    print(age - 1)
     
person(age =22, name ='suresh')
# Out:
# suresh
# 21

# %%
def person(name,age=18):
    print(name)
    print(age)
     
person('suresh Lingala', 23)
# Out:
# suresh Lingala
# 23

# %%
def sum(a, b):
    c = a+b
    return c
    
sum(5,6)
# Out:
# 11

# %%
def sum(a, b): 
    c = a+b
    return c
    
sum(5,6,7,8,9,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(5,6,7,8,9,10)
#
# TypeError: sum() takes 2 positional arguments but 6 were given

# %%
def sum(a, *b): 
    c = a+b
    return c
    
sum(5,6,7,8,9,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(5,6,7,8,9,10)
#
# Cell In[24], line 2, in sum(a, *b)
#       1 def sum(a, *b):
# ----> 2     c = a+b
#       3     return c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a, *b):
    c = a
    for i in b :
     c= c+i
     print(c)
    
sum(5,6,7,8,9,10)
# Out:
# 11
# 18
# 26
# 35
# 45

# %%
def sum(a, *b):
    c = a
    print(c)
    for i in b :
     c= c+i
     print(c)
    
sum(5,6,7,8,9,10)
# Out:
# 5
# 11
# 18
# 26
# 35
# 45

# %%
def person(name,*data):
  
    print(type(name))
    print(type(data))
    print(name)
    print(data)


person('Suresh Lingala', 36, 'hyderabad', 987767, ['hyd', 'sec'])
# Out:
# <class 'str'>
# <class 'tuple'>
# Suresh Lingala
# (36, 'hyderabad', 987767, ['hyd', 'sec'])

# %%
def person(name,**data):
    print(type(name))
    print(type(data))
    print(name)
    print(data)

person('Suresh lingala', age = 36, home_place ='southcity', mob =987767)
# Out:
# <class 'str'>
# <class 'dict'>
# Suresh lingala
# {'age': 36, 'home_place': 'southcity', 'mob': 987767}

# %%
a = 10  #-- globla variable 

def something():
    b = 15 #local variable
    
    print('in function',b)    
    print('out function',a)

# %%
a = 10  

def something():
    b = 15 
    print('in function',b)    
    
print('out function',a)
# Out:
# out function 10

# %%
a = 10  

def something():
    b = 15 
    print('in function',b)    
    
print('out function',a) 

something()
# Out:
# out function 10
# in function 15

# %%
x = 10  # Global variable

def update_x():
    global x  # Declare that we are using the global variable x
    x += 5    # Modify the global variable

update_x()
print(x)  # Output: 15
# Out:
# 15

# %%
x = 10  # Global variable

def update_x():
    globals()['x'] += 5  # Access and modify the global variable using the dictionary

update_x()
print(x)  # Output: 15
# Out:
# 15
