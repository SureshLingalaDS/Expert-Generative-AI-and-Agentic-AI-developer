# %%
'Welcome to 5:30 btach'
# Out:
# 'Welcome to 5:30 btach'

# %%
tup = ()

# %%
type(tup)
# Out:
# tuple

# %%
tup2 = (10,20,30,40,50)
tup2
# Out:
# (10, 20, 30, 40, 50)

# %%
tup3 =(10.55,11.32,12.34,14.54,23.34)
tup3
# Out:
# (10.55, 11.32, 12.34, 14.54, 23.34)

# %%
tup4 =('Apple','Bat','Cat')
tup4
# Out:
# ('Apple', 'Bat', 'Cat')

# %%
tup5 = (10,20.12,'Suresh',True,False,1+2j)

# %%
tup5
# Out:
# (10, 20.12, 'Suresh', True, False, (1+2j))

# %%
tup6 =(10,20.1,'Abc',[10,20.12,30],{40,50,60})
tup6
# Out:
# (10, 20.1, 'Abc', [10, 20.12, 30], {40, 50, 60})

# %%
len(tup6)
# Out:
# 5

# %%
tup6[1]
# Out:
# 20.1

# %%
tup6[4]
# Out:
# {40, 50, 60}

# %%
tup7 =(10,10,20,30)

# %%
tup7
# Out:
# (10, 10, 20, 30)

# %%
l =[10,20,30,40,40]
l
# Out:
# [10, 20, 30, 40, 40]

# %%
s={10,10,20,20,30,30,40,40,50}
s
# Out:
# {10, 20, 30, 40, 50}

# %%
tup6[4]
# Out:
# {40, 50, 60}

# %%
tup6[4]
# Out:
# {40, 50, 60}

# %%
tup6
# Out:
# (10, 20.1, 'Abc', [10, 20.12, 30], {40, 50, 60})

# %%
tup6[3][0]
# Out:
# 10

# %%
tup6[4]
# Out:
# {40, 50, 60}

# %%
tup6[-1]
# Out:
# {40, 50, 60}

# %%
tup6[-2]
# Out:
# [10, 20.12, 30]

# %%
tup6[:]
# Out:
# (10, 20.1, 'Abc', [10, 20.12, 30], {40, 50, 60})

# %%
tup6[:1]
# Out:
# (10,)

# %%
tup6[:-1]
# Out:
# (10, 20.1, 'Abc', [10, 20.12, 30])

# %%
tup6[::]
# Out:
# (10, 20.1, 'Abc', [10, 20.12, 30], {40, 50, 60})

# %%
tup6[1:1:1]
# Out:
# ()

# %%
sorted(tup6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sorted(tup6)
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
tup7 =(10,40,70,90,70,20,5,99,2,1)
tup7
# Out:
# (10, 40, 70, 90, 70, 20, 5, 99, 2, 1)

# %%
sorted(tup7)
# Out:
# [1, 2, 5, 10, 20, 40, 70, 70, 90, 99]

# %%
sorted(tup7, reverse=True)
# Out:
# [99, 90, 70, 70, 40, 20, 10, 5, 2, 1]

# %%
s ={10,20,30,40,50,60,70,80,90,90}
s
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80, 90}

# %%
s[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 s[0]=100
#
# TypeError: 'set' object does not support item assignment

# %%
len(s)
# Out:
# 9

# %%
s2={'dog','pig','tiger','apple','bat','cat'}
s2
# Out:
# {'apple', 'bat', 'cat', 'dog', 'pig', 'tiger'}

# %%
for i in s2:
    i

# %%
for i in enumerate(s2):
  print(i)
# Out:
# (0, 'apple')
# (1, 'Lion')
# (2, 'pig')
# (3, 'bat')
# (4, 'tiger')
# (5, 'eagle')
# (6, 'dog')
# (7, 'cat')

# %%
'apple' in s2
# Out:
# True

# %%
'Lion' in s2
# Out:
# False

# %%
'Lion' not in s2
# Out:
# True

# %%
s2.add('Lion')

# %% [raw]
# s2

# %%
s2.add('eagle')

# %%
s2.add('horse')
s2
# Out:
# {'Lion', 'apple', 'bat', 'cat', 'dog', 'eagle', 'horse', 'pig', 'tiger'}

# %%
s2.update(['TEN' , 'ELEVEN' , 'TWELVE']) # Add multiple item to a set using 
s2
# Out:
# {'ELEVEN',
#  'Lion',
#  'TEN',
#  'TWELVE',
#  'apple',
#  'bat',
#  'cat',
#  'dog',
#  'eagle',
#  'horse',
#  'pig',
#  'tiger'}

# %% [markdown]
# Dictionary

# %%
d=dict()

# %%
type(d)
# Out:
# dict

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
d={ 1:"one",2:"two",3:"three",4:"four"}
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
d[1]
# Out:
# 'one'

# %%
d[1]="ONE"

# %%
d
# Out:
# {1: 'ONE', 2: 'two', 3: 'three', 4: 'four'}

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
d.values()
# Out:
# dict_values(['ONE', 'two', 'three', 'four'])

# %%
d.items()
# Out:
# dict_items([(1, 'ONE'), (2, 'two'), (3, 'three'), (4, 'four')])
